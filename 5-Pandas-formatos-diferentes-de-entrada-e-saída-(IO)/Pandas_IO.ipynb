# %% [markdown]
# # Criando os nomes

# %%
import pandas as pd

# %%
nomes_f = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-f.json')
nomes_m = pd.read_json('https://guilhermeonrails.github.io/nomes_ibge/nomes-m.json')

# %%
nomes_f.sample(5)
# Out:
#           nome  regiao    freq  rank sexo
# 185     SHEILA       0   85939   186    F
# 157  CONCEICAO       0  102585   158    F
# 123      IVONE       0  131256   124    F
# 193   LUCILENE       0   82838   194    F
# 197    LUCIANE       0   81230   198    F

# %%
nomes_m.sample(5)
# Out:
#           nome  regiao     freq  rank sexo
# 10        LUIS       0   931530    11    M
# 137    AUGUSTO       0   104672   138    M
# 3    FRANCISCO       0  1765197     4    M
# 193      KAUAN       0    68526   194    M
# 126     MURILO       0   115067   127    M

# %%
print('Quantidade de nomes: ' + str(len(nomes_f) + len(nomes_m)))
# Out:
# Quantidade de nomes: 400

# %%
frames = [nomes_f, nomes_m]

# %%
nomes = pd.concat(frames)['nome'].to_frame()

# %%
nomes.sample(5)
# Out:
#          nome
# 138    CLEBER
# 53     ELAINE
# 106     ARTUR
# 97    OSVALDO
# 8    PATRICIA

# %% [markdown]
# # Incluindo ID dos alunos

# %%
import numpy as np
np.random.seed(123)

# %%
total_alunos = len(nomes)
total_alunos
# Out:
# 400

# %%
nomes['id_aluno'] = np.random.permutation(total_alunos) + 1

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno
# 188    POLIANA       369
# 57      DAIANE       303
# 3    FRANCISCO       382
# 182    CHARLES        33
# 30    ANDERSON       111

# %%
dominios = ['@dominiodoemmail.com.br', '@servicodoemail.com']
nomes['dominio'] = np.random.choice(dominios, total_alunos)

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno                  dominio
# 84    SEVERINO        78  @dominiodoemmail.com.br
# 0         JOSE       331      @servicodoemail.com
# 179       IAGO       340  @dominiodoemmail.com.br
# 10      SANDRA       174  @dominiodoemmail.com.br
# 171  TERESINHA        45  @dominiodoemmail.com.br

# %%
nomes['email'] = nomes.nome.str.cat(nomes.dominio).str.lower()

# %%
nomes.sample(5)
# Out:
#        nome  id_aluno                  dominio                          email
# 114  ARTHUR       320  @dominiodoemmail.com.br  arthur@dominiodoemmail.com.br
# 57   DAIANE       303      @servicodoemail.com      daiane@servicodoemail.com
# 85   HELENA       221  @dominiodoemmail.com.br  helena@dominiodoemmail.com.br
# 183   IRACI         8  @dominiodoemmail.com.br   iraci@dominiodoemmail.com.br
# 189   DALVA       137  @dominiodoemmail.com.br   dalva@dominiodoemmail.com.br

# %% [markdown]
# # Criando a tabela Cursos

# %%
# !pip3 install html5lib
# !pip3 install lxml

# %%
import html5lib

# %%
url = 'http://tabela-cursos.herokuapp.com/index.html'
cursos = pd.read_html(url)
cursos
# Out:
# [                          Nome do curso
#  0                 Lógica de programação
#  1                         Java para Web
#  2                           C# para Web
#  3                         Ruby on Rails
#  4                      Cursos de Python
#  5                         PHP com MySql
#  6                         .NET para web
#  7            Novas integrações com Java
#  8                          TDD com Java
#  9                   Código limpo com C#
#  10  Preparatório para certificação Java
#  11                      Hardware básico
#  12                Persistência com .NET
#  13                  Desenvolvendo jogos
#  14                     Análise de dados
#  15                   Estatística básica
#  16                  Internet das coisas
#  17                Programação funcional
#  18                Boas práticas em Java
#  19          Orientação objetos com Java]

# %%
type(cursos)
# Out:
# list

# %%
cursos = cursos[0]

# %%
type(cursos)
# Out:
# pandas.core.frame.DataFrame

# %%
cursos.head()
# Out:
#            Nome do curso
# 0  Lógica de programação
# 1          Java para Web
# 2            C# para Web
# 3          Ruby on Rails
# 4       Cursos de Python

# %% [markdown]
# # Alterando o index de cursos

# %%
cursos.rename(columns={'Nome do curso': 'nome_do_curso', 'Nome do curso': 'nome_do_curso'})
# Out:
#                           nome_do_curso
# 0                 Lógica de programação
# 1                         Java para Web
# 2                           C# para Web
# 3                         Ruby on Rails
# 4                      Cursos de Python
# 5                         PHP com MySql
# 6                         .NET para web
# 7            Novas integrações com Java
# 8                          TDD com Java
# 9                   Código limpo com C#
# 10  Preparatório para certificação Java
# 11                      Hardware básico
# 12                Persistência com .NET
# 13                  Desenvolvendo jogos
# 14                     Análise de dados
# 15                   Estatística básica
# 16                  Internet das coisas
# 17                Programação funcional
# 18                Boas práticas em Java
# 19          Orientação objetos com Java

# %%
cursos['id'] = cursos.index + 1

# %%
cursos.head()
# Out:
#            Nome do curso  id
# 0  Lógica de programação   1
# 1          Java para Web   2
# 2            C# para Web   3
# 3          Ruby on Rails   4
# 4       Cursos de Python   5

# %%
cursos = cursos.set_index('id')

# %%
cursos.head()
# Out:
#             Nome do curso
# id
# 1   Lógica de programação
# 2           Java para Web
# 3             C# para Web
# 4           Ruby on Rails
# 5        Cursos de Python

# %% [markdown]
# # Matriculando os alunos nos cursos

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                  dominio  \
# 59     ISABEL        83  @dominiodoemmail.com.br
# 172    REBECA       165      @servicodoemail.com
# 130    JUNIOR       184  @dominiodoemmail.com.br
# 70    JOAQUIM       248      @servicodoemail.com
# 171  VALDEMIR         3  @dominiodoemmail.com.br
#
#                                email
# 59     isabel@dominiodoemmail.com.br
# 172        rebeca@servicodoemail.com
# 130    junior@dominiodoemmail.com.br
# 70        joaquim@servicodoemail.com
# 171  valdemir@dominiodoemmail.com.br

# %%
nomes['matriculas'] = np.ceil(np.random.exponential(size=total_alunos) * 1.5).astype(int)

# %%
nomes.sample(5)
# Out:
#          nome  id_aluno                  dominio  \
# 133      RUAN       130      @servicodoemail.com
# 44   RAIMUNDA       259      @servicodoemail.com
# 50    RAFAELA        27  @dominiodoemmail.com.br
# 45    ADRIANO       196      @servicodoemail.com
# 117    PAMELA       189  @dominiodoemmail.com.br
#
#                               email  matriculas
# 133         ruan@servicodoemail.com           1
# 44      raimunda@servicodoemail.com           1
# 50   rafaela@dominiodoemmail.com.br           1
# 45       adriano@servicodoemail.com           2
# 117   pamela@dominiodoemmail.com.br           1

# %%
nomes.matriculas.describe()
# Out:
# count    400.000000
# mean       2.147500
# std        1.619352
# min        1.000000
# 25%        1.000000
# 50%        1.500000
# 75%        3.000000
# max       10.000000
# Name: matriculas, dtype: float64

# %%
import seaborn as sns

# %%
sns.distplot(nomes.matriculas)
# Out:
# C:\Users\nagah\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='matriculas', ylabel='Density'>

# %%
nomes.matriculas.value_counts()
# Out:
# 1     200
# 2      87
# 3      46
# 4      30
# 5      15
# 7       9
# 6       9
# 8       2
# 9       1
# 10      1
# Name: matriculas, dtype: int64

# %% [markdown]
# # Selecionando cursos

# %%
nomes.sample(5)
# Out:
#           nome  id_aluno                  dominio  \
# 97     BARBARA       201      @servicodoemail.com
# 170  ALEXANDRO       341      @servicodoemail.com
# 197    MICHAEL       323  @dominiodoemmail.com.br
# 196    ARLINDO        99      @servicodoemail.com
# 138      NEUSA        75  @dominiodoemmail.com.br
#
#                               email  matriculas
# 97       barbara@servicodoemail.com           1
# 170    alexandro@servicodoemail.com           1
# 197  michael@dominiodoemmail.com.br           2
# 196      arlindo@servicodoemail.com           1
# 138    neusa@dominiodoemmail.com.br           2

# %%
todas_matriculas = []
x = np.random.rand(20)
prob = x / sum(x)

# %%
for index, row in nomes.iterrows():
    id = row.id_aluno
    matriculas = row.matriculas
    for i in range(matriculas):
        mat = [id, np.random.choice(cursos.index, p = prob)]
        todas_matriculas.append(mat)

matriculas = pd.DataFrame(todas_matriculas, columns = ['id_aluno', 'id_curso'])

# %%
matriculas.head()
# Out:
#    id_aluno  id_curso
# 0       235         6
# 1       235        16
# 2        43         6
# 3        43        11
# 4        43        12

# %%
matriculas.groupby('id_curso').count().join(cursos['Nome do curso']). rename(columns={'id_aluno':'quantidade_de_alunos', 'Nome do curso': 'nome_do_curso'})
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           59                Lógica de programação
# 2                           31                        Java para Web
# 3                           53                          C# para Web
# 4                            4                        Ruby on Rails
# 5                           12                     Cursos de Python
# 6                           75                        PHP com MySql
# 7                           32                        .NET para web
# 8                           18           Novas integrações com Java
# 9                           59                         TDD com Java
# 10                          40                  Código limpo com C#
# 11                          61  Preparatório para certificação Java
# 12                          66                      Hardware básico
# 13                          14                Persistência com .NET
# ...

# %%
matriculas_por_curso = matriculas.groupby('id_curso').count().join(cursos['Nome do curso']). rename(columns={'id_aluno':'quantidade_de_alunos', 'Nome do curso': 'nome_do_curso'})

# %%
matriculas_por_curso.head()
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                           59  Lógica de programação
# 2                           31          Java para Web
# 3                           53            C# para Web
# 4                            4          Ruby on Rails
# 5                           12       Cursos de Python

# %% [markdown]
# # Saída em diferentes formatos

# %%
matriculas_por_curso.head(3)
# Out:
#           quantidade_de_alunos          nome_do_curso
# id_curso
# 1                           59  Lógica de programação
# 2                           31          Java para Web
# 3                           53            C# para Web

# %%
matriculas_por_curso.to_csv('matriculas_por_curso.csv', index = False)

# %%
pd.read_csv('matriculas_por_curso.csv')
# Out:
#     quantidade_de_alunos                        nome_do_curso
# 0                     59                Lógica de programação
# 1                     31                        Java para Web
# 2                     53                          C# para Web
# 3                      4                        Ruby on Rails
# 4                     12                     Cursos de Python
# 5                     75                        PHP com MySql
# 6                     32                        .NET para web
# 7                     18           Novas integrações com Java
# 8                     59                         TDD com Java
# 9                     40                  Código limpo com C#
# 10                    61  Preparatório para certificação Java
# 11                    66                      Hardware básico
# 12                    14                Persistência com .NET
# 13                    27                  Desenvolvendo jogos
# ...

# %%
matriculas_json = matriculas_por_curso.to_json()

# %%
matriculas_json
# Out:
# '{"quantidade_de_alunos":{"1":59,"2":31,"3":53,"4":4,"5":12,"6":75,"7":32,"8":18,"9":59,"10":40,"11":61,"12":66,"13":14,"14":27,"15":46,"16":43,"17":56,"18":53,"19":75,"20":35},"nome_do_curso":{"1":"L\\u00f3gica de programa\\u00e7\\u00e3o","2":"Java para Web","3":"C# para Web","4":"Ruby on Rails","5":"Cursos de Python","6":"PHP com MySql","7":".NET para web","8":"Novas integra\\u00e7\\u00f5es com Java","9":"TDD com Java","10":"C\\u00f3digo limpo com C#","11":"Preparat\\u00f3rio para certifica\\u00e7\\u00e3o Java","12":"Hardware b\\u00e1sico","13":"Persist\\u00eancia com .NET","14":"Desenvolvendo jogos","15":"An\\u00e1lise de dados","16":"Estat\\u00edstica b\\u00e1sica","17":"Internet das coisas","18":"Programa\\u00e7\\u00e3o funcional","19":"Boas pr\\u00e1ticas em Java","20":"Orienta\\u00e7\\u00e3o objetos com Java"}}'

# %%
matriculas_html = matriculas_por_curso.to_html()

# %%
print(matriculas_html)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>quantidade_de_alunos</th>
#       <th>nome_do_curso</th>
#     </tr>
#     <tr>
#       <th>id_curso</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>59</td>
#       <td>Lógica de programação</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>31</td>
#       <td>Java para Web</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>53</td>
#       <td>C# para Web</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4</td>
#       <td>Ruby on Rails</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>12</td>
#       <td>Cursos de Python</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>75</td>
#       <td>PHP com MySql</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>32</td>
#       <td>.NET para web</td>
#     </tr>
#     <tr>
#       <th>8</th>
# ...

# %% [markdown]
# # Criando o banco sql

# %%
# !pip install sqlalchemy

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect # adicionando o método inspect

engine = create_engine('sqlite:///:memory:')

# %%
engine
# Out:
# Engine(sqlite:///:memory:)

# %%
type(engine)
# Out:
# sqlalchemy.engine.base.Engine

# %%
matriculas_por_curso.to_sql('matriculas', engine)
# Out:
# 20

# %%
inspector = inspect(engine) # criando um Inspector object
print(inspector.get_table_names()) # Exibindo as tabelas com o inspecto
# Out:
# ['matriculas']

# %% [markdown]
# # Buscando do banco sql

# %%
query = 'select * from matriculas where quantidade_de_alunos < 20'

# %%
pd.read_sql(query, engine)
# Out:
#    id_curso  quantidade_de_alunos               nome_do_curso
# 0         4                     4               Ruby on Rails
# 1         5                    12            Cursos de Python
# 2         8                    18  Novas integrações com Java
# 3        13                    14       Persistência com .NET

# %%
pd.read_sql_table('matriculas', engine, columns = ['nome_do_curso', 'quantidade_de_alunos'])
# Out:
#                           nome_do_curso  quantidade_de_alunos
# 0                 Lógica de programação                    59
# 1                         Java para Web                    31
# 2                           C# para Web                    53
# 3                         Ruby on Rails                     4
# 4                      Cursos de Python                    12
# 5                         PHP com MySql                    75
# 6                         .NET para web                    32
# 7            Novas integrações com Java                    18
# 8                          TDD com Java                    59
# 9                   Código limpo com C#                    40
# 10  Preparatório para certificação Java                    61
# 11                      Hardware básico                    66
# 12                Persistência com .NET                    14
# 13                  Desenvolvendo jogos                    27
# ...

# %%
muitas_matriculas = pd.read_sql_table('matriculas', engine, columns = ['nome_do_curso', 'quantidade_de_alunos'])

# %%
muitas_matriculas = muitas_matriculas.query('quantidade_de_alunos > 80')

# %%
muitas_matriculas
# Out:
# Empty DataFrame
# Columns: [nome_do_curso, quantidade_de_alunos]
# Index: []

# %% [markdown]
# # Escrevendo no banco

# %%
muitas_matriculas.to_sql('muitas_matriculas', con = engine)
# Out:
# 0

# %%
print(engine.table_names())
# Out:
# ['matriculas', 'muitas_matriculas']
# C:\Users\nagah\AppData\Local\Temp\ipykernel_13240\1043810782.py:1: SADeprecationWarning: The Engine.table_names() method is deprecated and will be removed in a future release.  Please refer to Inspector.get_table_names(). (deprecated since: 1.4)
#   print(engine.table_names())

# %% [markdown]
# # Nomes dos alunos e alunas da próxima turma

# %%
matriculas_por_curso.head(20)
# Out:
#           quantidade_de_alunos                        nome_do_curso
# id_curso
# 1                           59                Lógica de programação
# 2                           31                        Java para Web
# 3                           53                          C# para Web
# 4                            4                        Ruby on Rails
# 5                           12                     Cursos de Python
# 6                           75                        PHP com MySql
# 7                           32                        .NET para web
# 8                           18           Novas integrações com Java
# 9                           59                         TDD com Java
# 10                          40                  Código limpo com C#
# 11                          61  Preparatório para certificação Java
# 12                          66                      Hardware básico
# 13                          14                Persistência com .NET
# ...

# %%
matriculas
# Out:
#      id_aluno  id_curso
# 0         235         6
# 1         235        16
# 2          43         6
# 3          43        11
# 4          43        12
# ..        ...       ...
# 854       383        12
# 855       366         1
# 856       366        19
# 857       366        10
# 858       366         6
#
# [859 rows x 2 columns]

# %%
id_curso = 16
proxima_turma = matriculas.query(f'id_curso == {id_curso}')

# %%
proxima_turma
# Out:
#      id_aluno  id_curso
# 1         235        16
# 6         304        16
# 13         55        16
# 23        218        16
# 44         80        16
# 95        259        16
# 136        21        16
# 150       108        16
# 176       179        16
# 183       275        16
# 210       377        16
# 222       148        16
# 231       149        16
# 304        36        16
# 326       399        16
# 329         5        16
# 342       153        16
# 352       202        16
# 417       389        16
# 427       369        16
# 432       346        16
# 438       222        16
# 466       208        16
# 468       390        16
# 477       162        16
# 528       364        16
# 551       196        16
# 564       164        16
# 585       170        16
# 601       392        16
# 631       251        16
# 637       255        16
# 650       110        16
# 651       110        16
# 669       266        16
# 681       320        16
# 750       279        16
# ...

# %%
nomes.sample(3)
# Out:
#          nome  id_aluno                  dominio  \
# 195    WALTER       231  @dominiodoemmail.com.br
# 90   ANDRESSA       213      @servicodoemail.com
# 191     ERICK       124  @dominiodoemmail.com.br
#
#                              email  matriculas
# 195  walter@dominiodoemmail.com.br           2
# 90     andressa@servicodoemail.com           1
# 191   erick@dominiodoemmail.com.br           1

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))
# Out:
#           id_curso       nome                  dominio  \
# id_aluno
# 5               16   SEVERINA  @dominiodoemmail.com.br
# 21              16     BIANCA      @servicodoemail.com
# 36              16     KARINA  @dominiodoemmail.com.br
# 48              16     ALISON      @servicodoemail.com
# 55              16     MARCIA  @dominiodoemmail.com.br
# 80              16    VITORIA      @servicodoemail.com
# 108             16      LUIZA      @servicodoemail.com
# 110             16    OSVALDO      @servicodoemail.com
# 110             16    OSVALDO      @servicodoemail.com
# 148             16      THAIS      @servicodoemail.com
# 149             16   MARILENE  @dominiodoemmail.com.br
# 153             16  CONCEICAO  @dominiodoemmail.com.br
# 162             16     RAFAEL      @servicodoemail.com
# 164             16      MARIO  @dominiodoemmail.com.br
# 170             16  REGINALDO      @servicodoemail.com
# 179             16       TAIS  @dominiodoemmail.com.br
# ...

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome']
# Out:
# id_aluno
# 5       SEVERINA
# 21        BIANCA
# 36        KARINA
# 48        ALISON
# 55        MARCIA
# 80       VITORIA
# 108        LUIZA
# 110      OSVALDO
# 110      OSVALDO
# 148        THAIS
# 149     MARILENE
# 153    CONCEICAO
# 162       RAFAEL
# 164        MARIO
# 170    REGINALDO
# 179         TAIS
# 196      ADRIANO
# 202        ESTER
# 208         LUIZ
# 214        JAIME
# 218       CAMILA
# 222      IVONETE
# 235        MARIA
# 251        MAURO
# 255       WESLEY
# 259     RAIMUNDA
# 266        CELSO
# 275         EDNA
# 279       WILIAN
# 304    FRANCISCA
# 320       ARTHUR
# 340         IAGO
# 346       LURDES
# 354     EDIVALDO
# 364      ROBERTO
# 369      POLIANA
# 377      VALERIA
# 385       MICHEL
# 389      LIDIANE
# 390       MARCOS
# 392       NELSON
# 398     CRISTIAN
# 399       CICERA
# Name: nome, dtype: object

# %%
proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))['nome'].to_frame()
# Out:
#                nome
# id_aluno
# 5          SEVERINA
# 21           BIANCA
# 36           KARINA
# 48           ALISON
# 55           MARCIA
# 80          VITORIA
# 108           LUIZA
# 110         OSVALDO
# 110         OSVALDO
# 148           THAIS
# 149        MARILENE
# 153       CONCEICAO
# 162          RAFAEL
# 164           MARIO
# 170       REGINALDO
# 179            TAIS
# 196         ADRIANO
# 202           ESTER
# 208            LUIZ
# 214           JAIME
# 218          CAMILA
# 222         IVONETE
# 235           MARIA
# 251           MAURO
# 255          WESLEY
# 259        RAIMUNDA
# 266           CELSO
# 275            EDNA
# 279          WILIAN
# 304       FRANCISCA
# 320          ARTHUR
# 340            IAGO
# 346          LURDES
# 354        EDIVALDO
# 364         ROBERTO
# 369         POLIANA
# 377         VALERIA
# 385          MICHEL
# 389         LIDIANE
# 390          MARCOS
# 392          NELSON
# 398        CRISTIAN
# 399          CICERA

# %%
nome_curso = cursos.loc[id_curso]
nome_curso
# Out:
# Nome do curso    Estatística básica
# Name: 16, dtype: object

# %%
proxima_turma = proxima_turma.set_index('id_aluno').join(nomes.set_index('id_aluno'))

# %%
proxima_turma
# Out:
#           id_curso       nome                  dominio  \
# id_aluno
# 5               16   SEVERINA  @dominiodoemmail.com.br
# 21              16     BIANCA      @servicodoemail.com
# 36              16     KARINA  @dominiodoemmail.com.br
# 48              16     ALISON      @servicodoemail.com
# 55              16     MARCIA  @dominiodoemmail.com.br
# 80              16    VITORIA      @servicodoemail.com
# 108             16      LUIZA      @servicodoemail.com
# 110             16    OSVALDO      @servicodoemail.com
# 110             16    OSVALDO      @servicodoemail.com
# 148             16      THAIS      @servicodoemail.com
# 149             16   MARILENE  @dominiodoemmail.com.br
# 153             16  CONCEICAO  @dominiodoemmail.com.br
# 162             16     RAFAEL      @servicodoemail.com
# 164             16      MARIO  @dominiodoemmail.com.br
# 170             16  REGINALDO      @servicodoemail.com
# 179             16       TAIS  @dominiodoemmail.com.br
# ...

# %%
proxima_turma.rename(columns = {'nome' : 'Alunos do curso de Estatística Básica'})
# Out:
#           id_curso Alunos do curso de Estatística Básica  \
# id_aluno
# 5               16                              SEVERINA
# 21              16                                BIANCA
# 36              16                                KARINA
# 48              16                                ALISON
# 55              16                                MARCIA
# 80              16                               VITORIA
# 108             16                                 LUIZA
# 110             16                               OSVALDO
# 110             16                               OSVALDO
# 148             16                                 THAIS
# 149             16                              MARILENE
# 153             16                             CONCEICAO
# 162             16                                RAFAEL
# 164             16                                 MARIO
# 170             16                             REGINALDO
# ...

# %%
proxima_turma.sample(5)
# Out:
#           id_curso      nome                  dominio  \
# id_aluno
# 218             16    CAMILA  @dominiodoemmail.com.br
# 279             16    WILIAN      @servicodoemail.com
# 108             16     LUIZA      @servicodoemail.com
# 398             16  CRISTIAN      @servicodoemail.com
# 340             16      IAGO  @dominiodoemmail.com.br
#
#                                   email  matriculas
# id_aluno
# 218       camila@dominiodoemmail.com.br           1
# 279           wilian@servicodoemail.com           2
# 108            luiza@servicodoemail.com           7
# 398         cristian@servicodoemail.com           3
# 340         iago@dominiodoemmail.com.br           2

# %% [markdown]
# # Excel

# %%
proxima_turma.to_excel('proxima_turma.xlsx', index=False)

# %%
pd.read_excel('proxima_turma.xlsx')
# Out:
#     id_curso       nome                  dominio  \
# 0         16   SEVERINA  @dominiodoemmail.com.br
# 1         16     BIANCA      @servicodoemail.com
# 2         16     KARINA  @dominiodoemmail.com.br
# 3         16     ALISON      @servicodoemail.com
# 4         16     MARCIA  @dominiodoemmail.com.br
# 5         16    VITORIA      @servicodoemail.com
# 6         16      LUIZA      @servicodoemail.com
# 7         16    OSVALDO      @servicodoemail.com
# 8         16    OSVALDO      @servicodoemail.com
# 9         16      THAIS      @servicodoemail.com
# 10        16   MARILENE  @dominiodoemmail.com.br
# 11        16  CONCEICAO  @dominiodoemmail.com.br
# 12        16     RAFAEL      @servicodoemail.com
# 13        16      MARIO  @dominiodoemmail.com.br
# 14        16  REGINALDO      @servicodoemail.com
# 15        16       TAIS  @dominiodoemmail.com.br
# 16        16    ADRIANO      @servicodoemail.com
# 17        16      ESTER      @servicodoemail.com
# ...
